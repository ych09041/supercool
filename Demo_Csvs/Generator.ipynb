# %%
# %matplotlib inline

import math
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.io
import random
import sklearn.preprocessing
import csv
from numpy import linalg as LA
import scipy.stats.mstats as mstats
from sklearn.feature_extraction import DictVectorizer
import pickle
import time

import pdb

# %% [markdown]
# # Circle

# %%
amp1 = 10
amp2 = 10
t= np.linspace(0,3, 180)
out1 = (amp1*np.sin(2*np.pi*t)).astype(int)
out3 = (-amp1*np.sin(2*np.pi*t)).astype(int)
out2 = (amp2*np.cos(2*np.pi*t)).astype(int)
out4 = (-amp2*np.cos(2*np.pi*t)).astype(int)

# plt.figure()
# plt.plot(t, out1, t, out3)
# plt.figure()
# plt.plot(t, out2, t, out4)
# plt.xticks(rotation = 45)
# plt.xlabel('Iterations')
# plt.ylabel('Risk')
# plt.title('Training Risk for MSE')
# plt.savefig('MSE/mseRisk.png',bbox_inches = 'tight')

# %% [markdown]
# ## Write for Four Links

# %%
with open(str(amp1)+str(amp2)+'gyrate_4links.csv', 'wb') as csvfile:
    sampleWriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(t)):
        sampleWriter.writerow([out1[i],out2[i], out3[i], out4[i]])

# %% [markdown]
# ## Write for Three Links

# %%
with open(str(amp1)+str(amp2)+'gyrate_3links.csv', 'wb') as csvfile:
    sampleWriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(t)):
        sampleWriter.writerow([out1[i],out2[i], out3[i]])

# %% [markdown]
# ## Write for Two Links

# %%
with open(str(amp1)+str(amp2)+'gyrate_2links.csv', 'wb') as csvfile:
    sampleWriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(t)):
        sampleWriter.writerow([out1[i],out2[i]])

# %% [markdown]
# ## Write for One Link

# %%
with open(str(amp1)+str(amp2)+'gyrate_1link.csv', 'wb') as csvfile:
    sampleWriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(t)):
        sampleWriter.writerow([out1[i]])

# %% [markdown]
# # Figure 8

# %%
amp1 = 10
amp2 = 10
t= np.linspace(0,3, 180)
out1 = (amp1*np.sin(2*np.pi*t)).astype(int)
out3 = (-amp1*np.sin(2*np.pi*t)).astype(int)
out2 = (amp2*np.cos(4*np.pi*t)).astype(int)
out4 = (-amp2*np.cos(4*np.pi*t)).astype(int)

# plt.figure()
# plt.plot(t, out1, t, out3)
# plt.figure()
# plt.plot(t, out2, t, out4)
# plt.xticks(rotation = 45)
# plt.xlabel('Iterations')
# plt.ylabel('Risk')
# plt.title('Training Risk for MSE')
# plt.savefig('MSE/mseRisk.png',bbox_inches = 'tight')

# %% [markdown]
# ## Write for Four Links

# %%
with open(str(amp1)+str(amp2)+'figure8_4links.csv', 'wb') as csvfile:
    sampleWriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(t)):
        sampleWriter.writerow([out1[i],out2[i], out3[i], out4[i]])
